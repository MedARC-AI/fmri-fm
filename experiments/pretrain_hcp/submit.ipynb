# %%
from lightning_sdk import Studio, Machine, Job

# %%
studio = Studio(name="connor-pretrain", teamspace="medarc", org="medarc")

# %%
job = Job.run(
    command="bash fmri-fm/experiments/pretrain_hcp/launch_pretrain.sh",
    name="pretrain_hcp",
    machine=Machine.H100,
    studio=studio,
    interruptible=True,
)
